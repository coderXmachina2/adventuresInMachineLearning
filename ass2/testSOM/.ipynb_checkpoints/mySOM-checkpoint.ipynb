# %%
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from time import time
import sompy

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# Out:
# Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
dFrame = pd.read_csv('somDataset.csv')

# %%
quakeRecArr  = dFrame.to_records(index=False)

# %%
print(quakeRecArr.dtype.names)
# Out:
# ('longitude', ' latitude', ' magnitude', ' depth')

# %%
from matplotlib import pyplot as plot

figure = plot.figure()
ax = figure.add_subplot(111)
ax.plot(quakeRecArr['longitude'], 
        quakeRecArr[' latitude'], 
        quakeRecArr[' magnitude'], 
        '*b',alpha=0.9,
        markersize=2)

ax.set_xlim([0, 2000])
ax.set_ylim([0, 5])

figure.set_size_inches(10,10)
    
ax.set_xlabel('$Is this x Label$')
ax.set_ylabel('$Or is this y?$')

plot.grid()
plot.show()
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()

ax = fig.add_subplot( 111 , projection='3d')
plot.suptitle('3D Latitude Longitude and Magnitude', fontsize=16)
ax.plot(quakeRecArr['longitude'], 
        quakeRecArr[' latitude'], 
        quakeRecArr[' magnitude'],  
        'ob', alpha=0.2, markersize=2)

plot.axvline(x=172.16794, color = 'red', alpha=0.2, markersize=2)
plot.axhline(y=-43.52731, color = 'red', alpha=0.2, markersize=2)

ax.set_xlabel('\nLongitude')
ax.set_ylabel('\nLatitude')

fig.set_size_inches(10,10)

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(quakeRecArr['longitude'], 
        quakeRecArr[' latitude'], 
        quakeRecArr[' depth'],  
        'ob', alpha=0.2, markersize=2)

fig.set_size_inches(10,10)

plt.show()
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos

# %%
dFrame = pd.read_csv('somDataset2.csv')
quakeDat = dFrame.to_records(index=False)
type(quakeDat) #this is a record array

quakeDatNP = np.array(quakeDat.tolist())
type(quakeDatNP)

#quakeDat = quakeDat.view((float, len(quakeDat.dtype.names)))
#print("print p")
#type(p)

mapsize = [50,50] #
som = sompy.SOMFactory.build(quakeDatNP, mapsize, mask=None, mapshape='planar', lattice='rect', normalization='var', initialization='pca', neighborhood='gaussian', training='batch', name='sompy')  # this will use the default parameters, but i can change the initialization and neighborhood methods
som.train(n_job=1, verbose='info')  # verbose='debug' will print more, and verbose=None wont print anything
# Out:
#  Training...
#  pca_linear_initialization took: 0.080000 seconds
#  Rough training...
#  radius_ini: 7.000000 , radius_final: 1.750000, trainlen: 23
#
#  epoch: 1 ---> elapsed time:  0.330000, quantization error: 1.038372
#
#  epoch: 2 ---> elapsed time:  0.337000, quantization error: 0.821480
#
#  epoch: 3 ---> elapsed time:  0.323000, quantization error: 0.698724
#
#  epoch: 4 ---> elapsed time:  0.335000, quantization error: 0.654755
#
#  epoch: 5 ---> elapsed time:  0.335000, quantization error: 0.630539
#
#  epoch: 6 ---> elapsed time:  0.310000, quantization error: 0.610693
#
#  epoch: 7 ---> elapsed time:  0.309000, quantization error: 0.592733
#
#  epoch: 8 ---> elapsed time:  0.336000, quantization error: 0.576045
#
#  epoch: 9 ---> elapsed time:  0.335000, quantization error: 0.559248
#
#  epoch: 10 ---> elapsed time:  0.329000, quantization error: 0.542434
#
#  epoch: 11 ---> elapsed time:  0.335000, quantization error: 0.526006
#
#  epoch: 12 ---> elapsed time:  0.356000, quantization error: 0.510039
#
#  epoch: 13 ---> elapsed time:  0.313000, quantization error: 0.494624
#
#  epoch: 14 ---> elapsed time:  0.328000, quantization error: 0.479133
#
#  epoch: 15 ---> elapsed time:  0.326000, quantization error: 0.462630
#
#  epoch: 16 ---> elapsed time:  0.323000, quantization error: 0.444786
#
#  epoch: 17 ---> elapsed time:  0.330000, quantization error: 0.427047
#
#  epoch: 18 ---> elapsed time:  0.327000, quantization error: 0.409097
#
#  epoch: 19 ---> elapsed time:  0.334000, quantization error: 0.391101
#
#  epoch: 20 ---> elapsed time:  0.334000, quantization error: 0.371446
#
#  epoch: 21 ---> elapsed time:  0.311000, quantization error: 0.351999
#
#  epoch: 22 ---> elapsed time:  0.302000, quantization error: 0.332418
#
#  epoch: 23 ---> elapsed time:  0.347000, quantization error: 0.312403
#
#  Finetune training...
#  radius_ini: 1.750000 , radius_final: 1.000000, trainlen: 31
#
#  epoch: 1 ---> elapsed time:  0.315000, quantization error: 0.291897
#
#  epoch: 2 ---> elapsed time:  0.324000, quantization error: 0.287839
#
#  epoch: 3 ---> elapsed time:  0.333000, quantization error: 0.283797
#
#  epoch: 4 ---> elapsed time:  0.340000, quantization error: 0.280694
#
#  epoch: 5 ---> elapsed time:  0.476000, quantization error: 0.277922
#
#  epoch: 6 ---> elapsed time:  0.498000, quantization error: 0.275350
#
#  epoch: 7 ---> elapsed time:  0.879000, quantization error: 0.272862
#
#  epoch: 8 ---> elapsed time:  0.469000, quantization error: 0.270278
#
#  epoch: 9 ---> elapsed time:  0.325000, quantization error: 0.267563
#
#  epoch: 10 ---> elapsed time:  0.345000, quantization error: 0.265136
#
#  epoch: 11 ---> elapsed time:  0.431000, quantization error: 0.262713
#
#  epoch: 12 ---> elapsed time:  0.312000, quantization error: 0.260332
#
#  epoch: 13 ---> elapsed time:  0.312000, quantization error: 0.257898
#
#  epoch: 14 ---> elapsed time:  0.332000, quantization error: 0.255463
#
#  epoch: 15 ---> elapsed time:  0.323000, quantization error: 0.252917
#
#  epoch: 16 ---> elapsed time:  0.368000, quantization error: 0.250328
#
#  epoch: 17 ---> elapsed time:  0.390000, quantization error: 0.247829
#
#  epoch: 18 ---> elapsed time:  0.366000, quantization error: 0.245185
#
#  epoch: 19 ---> elapsed time:  0.392000, quantization error: 0.242533
#
#  epoch: 20 ---> elapsed time:  0.373000, quantization error: 0.239910
#
#  epoch: 21 ---> elapsed time:  0.403000, quantization error: 0.237370
#
#  epoch: 22 ---> elapsed time:  0.404000, quantization error: 0.234677
#
#  epoch: 23 ---> elapsed time:  0.425000, quantization error: 0.231936
#
#  epoch: 24 ---> elapsed time:  0.404000, quantization error: 0.228966
#
#  epoch: 25 ---> elapsed time:  0.413000, quantization error: 0.225986
#
#  epoch: 26 ---> elapsed time:  0.450000, quantization error: 0.223085
#
#  epoch: 27 ---> elapsed time:  0.446000, quantization error: 0.220171
#
#  epoch: 28 ---> elapsed time:  0.489000, quantization error: 0.217424
#
#  epoch: 29 ---> elapsed time:  0.505000, quantization error: 0.214772
#
#  epoch: 30 ---> elapsed time:  0.523000, quantization error: 0.211774
#
#  epoch: 31 ---> elapsed time:  0.558000, quantization error: 0.208789
#
#  Final quantization error: 0.208789
#  train took: 20.600000 seconds

# %%
v = sompy.mapview.View2DPacked(50, 50, 'test',text_size=8)  
v

# %%
v = sompy.mapview.View2DPacked(50, 50, 'test',text_size=8)  
# could be done in a one-liner: sompy.mapview.View2DPacked(300, 300, 'test').show(som)
v.show(som, what='codebook', which_dim=[0,1,2,3], cmap=None, col_sz=6) #which_dim='all' default
# v.save('2d_packed_test')

# %%
som.component_names = ['1','2','3','4']
v = sompy.mapview.View2DPacked(50, 50, 'test',text_size=8)  
v.show(som, what='codebook', which_dim='all', cmap='jet', col_sz=6) #which_dim='all' default

# %%
# c = sompy.mapview.View2DPacked()
v = sompy.mapview.View2DPacked(2, 2, 'test',text_size=8)  
#first you can do clustering. Currently only K-means on top of the trained som
cl = som.cluster(n_clusters=4)
# print cl
getattr(som, 'cluster_labels')
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
v.show(som, what='cluster')
# Out:
# C:\Users\afiqAUT\Anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
h = sompy.hitmap.HitMapView(10, 10, 'hitmap', text_size=10, show_text=True)
h.show(som)

# %%
h2 = sompy.hitmap.HitMapView(10, 10, 'hitmap', text_size=12, show_text=True)
h2.show(som)

# %%
u = sompy.umatrix.UMatrixView(50, 50, 'umatrix', show_axis=True, text_size=8, show_text=True)

#This is the Umat value
UMAT  = u.build_u_matrix(som, distance=1, row_normalized=False)

#Here you have Umatrix plus its render
UMAT = u.show(som, distance2=1, row_normalized=False, show_data=True, contooor=True, blob=False)
