# %%
#first call dependencies
import pandas as pd
import numpy as np

# %%
#import dataset

dFrame = pd.read_csv('aftershockLLMD.csv')
dFrame
# Out:
#       longitude   latitude   magnitude    depth
# 0     172.16794  -43.52731       7.200  11.0426
# 1     172.32367  -43.55426       5.815  10.0257
# 2     172.38512  -43.65850       5.114   7.8273
# 3     172.29477  -43.56610       5.532  11.8823
# 4     172.18575  -43.47110       5.434   6.2919
# 5     172.11847  -43.49201       5.162  10.1591
# 6     172.11028  -43.62283       5.335  17.6058
# 7     172.21217  -43.59541       4.921  14.2405
# 8     172.42960  -43.68362       4.565   8.3170
# 9     172.54439  -43.58787       4.750  24.8006
# 10    172.30362  -43.58586       4.971   9.8851
# 11    172.37521  -43.66354       4.822   5.0000
# 12    172.23647  -43.64153       4.945  11.2593
# 13    172.27835  -43.63268       4.912   8.1763
# 14    172.41315  -43.60732       4.979   9.3622
# 15    172.16673  -43.60926       5.144   9.4878
# 16    172.27443  -43.61766       4.569  12.7419
# 17    172.40707  -43.64999       4.491  11.3240
# 18    172.16286  -43.46124       5.359   6.6817
# ...

# %%
quakeRecArr  = dFrame.to_records(index=False)

quakeRecArr
# Out:
# rec.array([(172.16794, -43.52731, 7.2  , 11.0426),
#            (172.32367, -43.55426, 5.815, 10.0257),
#            (172.38512, -43.6585 , 5.114,  7.8273), ...,
#            (171.88284, -43.59351, 2.461,  5.    ),
#            (172.41629, -43.64249, 3.559, 14.2303),
#            (171.75114, -43.56247, 2.662,  5.    )],
#           dtype=[('longitude', '<f8'), (' latitude', '<f8'), (' magnitude', '<f8'), (' depth', '<f8')])

# %%
type(quakeRecArr) #this is a records array
# Out:
# numpy.recarray

# %%
quakeLLMD = np.array(quakeRecArr.tolist())
quakeLLMD
# Out:
# array([[172.16794, -43.52731,   7.2    ,  11.0426 ],
#        [172.32367, -43.55426,   5.815  ,  10.0257 ],
#        [172.38512, -43.6585 ,   5.114  ,   7.8273 ],
#        ...,
#        [171.88284, -43.59351,   2.461  ,   5.     ],
#        [172.41629, -43.64249,   3.559  ,  14.2303 ],
#        [171.75114, -43.56247,   2.662  ,   5.     ]])

# %%
def eyeBallData (data):
    N = len(data)
    firstEntry = data[0]
    firstV = data[:5]
    lastInst = data[N-1]
    Nattr = len(data[0])
    nomDtype = data.dtype.names
    
    return (N, firstEntry, firstV , lastInst , Nattr, nomDtype)

decomposeData = eyeBallData(quakeLLMD)

print("The dataset quake Aftershock has " + str(decomposeData[0]) + " entries.\n\n" +
      "Here is the first Entry:\n" + str(decomposeData[1]) + "\n\n" +
      "Here are the first 5:\n" + str(decomposeData[2]) + "\n\n" +
      "Here is the last one:\n" + str(decomposeData[3]) + "\n\n" + #last
      "Each entry has: " + str(decomposeData[4]) + ' attributes. They are ' + str(decomposeData[5])
     )
# Out:
# The dataset quake Aftershock has 3290 entries.
#
# Here is the first Entry:
# [172.16794 -43.52731   7.2      11.0426 ]
#
# Here are the first 5:
# [[172.16794 -43.52731   7.2      11.0426 ]
#  [172.32367 -43.55426   5.815    10.0257 ]
#  [172.38512 -43.6585    5.114     7.8273 ]
#  [172.29477 -43.5661    5.532    11.8823 ]
#  [172.18575 -43.4711    5.434     6.2919 ]]
#
# Here is the last one:
# [171.75114 -43.56247   2.662     5.     ]
#
# Each entry has: 4 attributes. They are None

# %%
quakeLLMD[:,0] #all of longitude
# Out:
# array([172.16794, 172.32367, 172.38512, ..., 171.88284, 172.41629,
#        171.75114])

# %%
quakeLLMD[:,1] #all of latitude
# Out:
# array([-43.52731, -43.55426, -43.6585 , ..., -43.59351, -43.64249,
#        -43.56247])

# %%
quakeLLMD[:,2] #all of magnitude
# Out:
# array([7.2  , 5.815, 5.114, ..., 2.461, 3.559, 2.662])

# %%
quakeLLMD[:,3] #all of depth
# Out:
# array([11.0426, 10.0257,  7.8273, ...,  5.    , 14.2303,  5.    ])

# %%
from matplotlib import pyplot as plot

def plotPos(datTable):  
    
    figure = plot.figure()
    ax = figure.add_subplot(111)
    plot.suptitle('Latitude and Longitude and Longitude plots of datapoints', fontsize=24)
    ax.plot(quakeLLMD[:,0],
            quakeLLMD[:,1], 
            's', 
            ms=1.2, 
            c='red' , 
            mew = 1.2, 
            alpha = 12.0,
            )
    
    figure.set_size_inches(10,6)
    
    #FInd that Bloody Outlier
    #plot.axvline(x=172.925, color = 'red', alpha=0.2, markersize=2)
    #plot.axhline(y=-42.673, color = 'red', alpha=0.2, markersize=2)
    
    plot.axvline(x=172.16794, color = 'green', alpha=0.2, markersize=2)
    plot.axhline(y=-43.52731, color = 'green', alpha=0.2, markersize=2)
    
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    plot.grid(c='blue')
    plot.show()
    
    #plot points
    
plotPos(quakeLLMD)

# %%
#create a new column that has all 

for t in range (0, 3290):
    print(str(      round(quakeLLMD[t][0],4)         ) + " " +  str(round( quakeLLMD[t][1], 4)      ))
# Out:
# 172.1679 -43.5273
# 172.3237 -43.5543
# 172.3851 -43.6585
# 172.2948 -43.5661
# 172.1858 -43.4711
# 172.1185 -43.492
# 172.1103 -43.6228
# 172.2122 -43.5954
# 172.4296 -43.6836
# 172.5444 -43.5879
# 172.3036 -43.5859
# 172.3752 -43.6635
# 172.2365 -43.6415
# 172.2784 -43.6327
# 172.4132 -43.6073
# 172.1667 -43.6093
# 172.2744 -43.6177
# 172.4071 -43.65
# 172.1629 -43.4612
# 172.4009 -43.6071
# 172.17 -43.4763
# 172.2381 -43.572
# 171.9002 -43.6457
# 172.3577 -43.6156
# 172.1995 -43.618
# 172.4482 -43.6536
# 172.3221 -43.6086
# 172.4878 -43.5487
# 172.152 -43.5216
# 172.3687 -43.6056
# 172.4028 -43.5992
# 172.2051 -43.6309
# 172.2546 -43.6209
# 172.1237 -43.6544
# 172.4125 -43.4722
# 172.2026 -43.6018
# 172.21 -43.6162
# 172.4227 -43.6018
# 172.2241 -43.6067
# 172.3921 -43.6193
# 172.5451 -43.615
# 171.9654 -43.4238
# 172.2784 -43.6232
# 172.379 -43.5513
# 172.241 -43.6286
# 172.113 -43.5491
# 172.4544 -43.6175
# 172.3783 -43.411
# 172.4102 -43.604
# 171.9603 -43.5144
# ...

# %%
quakeLLMD[0][0] #[instance][atrribure]
# Out:
# 172.16794

# %%
quakeLLMD[0][1]
# Out:
# -43.52731

# %%
quakeLLMD[0][2]
# Out:
# 7.2

# %%
quakeLLMD[0][3]
# Out:
# 11.0426

# %%
with open('apiKey.txt') as f:
    api_key = f.readline()
    #print(api_key)
    f.close

# %%
import gmaps
gmaps.configure(api_key='AIzaSyAa4cJty_xhjmlFJV87RZsmr5SBb9cYUHA')
new_york_coordinates = (40.75, -74.00)
gmaps.figure(center=new_york_coordinates, zoom_level=12)
# Out:
# Figure(layout=FigureLayout(height='420px'))
